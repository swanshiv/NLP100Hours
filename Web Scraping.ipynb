# %%
import requests
web_page = requests.get("https://www.thebetterindia.com/102639/fight-right-to-education-anurag-kundu")
web_page
# Out:
# <Response [200]>

# %%
print (web_page.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 8]>\n<html class="no-js lt-ie10 lt-ie9" id="ie8" lang="en-US"\n xmlns:og="http://opengraphprotocol.org/schema/"\n xmlns:fb="http://www.facebook.com/2008/fbml" prefix="og: http://ogp.me/ns#"><![endif]-->\n<!--[if IE 9]>\n<html class="no-js lt-ie10" id="ie9" lang="en-US"\n xmlns:og="http://opengraphprotocol.org/schema/"\n xmlns:fb="http://www.facebook.com/2008/fbml" prefix="og: http://ogp.me/ns#"><![endif]-->\n<!--[if !IE]><!-->\n<html class="no-js" lang="en-US"\n xmlns:og="http://opengraphprotocol.org/schema/"\n xmlns:fb="http://www.facebook.com/2008/fbml" prefix="og: http://ogp.me/ns#"><!--<![endif]-->\n<head>\n\t<meta charset="UTF-8"/>\n\t<link rel="profile" href="https://gmpg.org/xfn/11"/>\n\t<link rel="pingback" href="https://www.thebetterindia.com/xmlrpc.php"/>\n\n\t<title>Anurag Kundu Is Helping Make the Right to Education a Universal Truth</title>\n\n<meta name="viewport" content="initial-scale=1.0, width=device-width" />\n\n<!-- This site is optim
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(web_page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>
# <html class="no-js lt-ie10 lt-ie9" id="ie8" lang="en-US"
#  xmlns:og="http://opengraphprotocol.org/schema/"
#  xmlns:fb="http://www.facebook.com/2008/fbml" prefix="og: http://ogp.me/ns#"><![endif]-->
# <!--[if IE 9]>
# <html class="no-js lt-ie10" id="ie9" lang="en-US"
#  xmlns:og="http://opengraphprotocol.org/schema/"
#  xmlns:fb="http://www.facebook.com/2008/fbml" prefix="og: http://ogp.me/ns#"><![endif]-->
# <!--[if !IE]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.thebetterindia.com/xmlrpc.php" rel="pingback"/>
#   <title>
#    Anurag Kundu Is Helping Make the Right to Education a Universal Truth
#   </title>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
# ...

# %%
for item in soup.find_all('div', class = )
